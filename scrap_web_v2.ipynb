# %%
import csv
import time
import math
import regex as re
import os
from datetime import datetime
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.support import expected_conditions as EC
from selenium.common.exceptions import NoSuchElementException

import locale
locale.setlocale(locale.LC_TIME, 'id-ID.UTF-8')
# Out:
# 'id-ID.UTF-8'

# %%
def check_exists_by_xpath(xpath):
    try:
        driver.find_element_by_xpath(xpath)
    except NoSuchElementException:
        return False
    return True

# %% [markdown]
# # Set Target

# %%
target = [
    "https://www.happyfresh.id/hypermart-ar-hakim",
    "https://www.happyfresh.id/hero-tunjungan-plaza/",
    "https://www.happyfresh.id/farmers-market-kupang-indah/",
    "https://www.happyfresh.id/papaya-fresh-gallery-margorejo/",
    "https://www.happyfresh.id/freshco-market-grand-city/"
]
category = [
    "fresh-produce-2",
    "pantry-and-ingredients-48",
    "meat-seafood-7",
    "dairy-eggs-24",
    "chilled-and-frozen-70"
]
plus = '?page='

# %% [markdown]
# # Start Scrap

# %%
datenow = datetime.date(datetime.now()).strftime('%d%m%Y')
os.mkdir(datenow)

# %%
# Looping  for each url on list
for url in target :
    s = Service('D:\Ternaknesia\Web Scrapping\chromedriver.exe')
    driver = webdriver.Chrome(service=s)
    actionChain = webdriver.ActionChains(driver)
    time.sleep(3)
    
    outlet = url.split('/')[3]
    csvFile = open("D:/Ternaknesia/Web Scrapping/%s/scrapped_%s.csv" % (datenow, outlet,), 'a', newline='')
    csvWriter = csv.writer(csvFile)
    csvWriter.writerow(['Kategori','Nama','Pack','Harga', 'Satuan', 'Harga per unit'])
    
    print("==> ", outlet, " <==")
    print("========================================")
    
    for cat in category :
        
        driver.get(url+cat)
        cat_name = cat.replace("-", " ").rsplit(' ', 1)[0]
    
        if (check_exists_by_xpath(".//span[@class='jsx-4062261742 count']")):
            #get total item and total pages
            totproduct = int(driver.find_element_by_xpath(".//span[@class='jsx-4062261742 count']").text);
            totpage = math.ceil(totproduct/20)

            #Looping each pages
            for i in range(0,totpage):
                container = driver.find_elements_by_xpath("//div[@class='jsx-2751153571 root small PLP-Common-"+cat+"-product-container']")
                num_page_items = len(container);
                pagenow = i+1
                print(cat_name, "=> Page : ", pagenow, "/", totpage, end = ' ')
    #print("Total Items on Page : ", num_page_items)

                #Looping each product in pages
                for j in range(num_page_items):
              #time.sleep(1)

                    # to save product name
                    name = container[j].find_element_by_xpath(".//h2[@class='jsx-2751153571 jsx-717190455']").text.encode("utf-8", "ignore")
    #                 print(name)

                    # to save product qty
                    packaging = container[j].find_element_by_xpath(".//div[@class='jsx-2751153571 jsx-717190455 unit']").text;
    #                 print(packaging)

                    # to save harga
                    price = container[j].find_element_by_xpath(".//span[@class='jsx-2751153571 jsx-717190455 price']").text;
                    if (price == ''):
                        price = container[j].find_element_by_xpath(".//div[@class='jsx-2751153571 jsx-717190455 price PLP-Common-"+cat+"-discount-price']").text;
    #                 print(price)

                    # to save gramasi produk
                    if (check_exists_by_xpath("//div[@class='jsx-2751153571 jsx-717190455 unit-price']")):
                        gram = container[j].find_element_by_xpath(".//div[@class='jsx-2751153571 jsx-717190455 unit-price']").text;
                        if gram == "":
                            unitprice = 0
                            satuan = 0
                        else:
                            unitprice = gram.split('/')[0]
                            satuan = gram.split('/')[1]
        #print(unitprice)
        #print(satuan)

                    # to save in a csv file readable
                    csvWriter.writerow([cat_name, name, packaging, price, satuan, unitprice])

                # to change the page
                print("Done!")
                if pagenow != totpage:
                    driver.get(url+cat+plus+str(pagenow+1))
        else :
            print(cat_name+" => No Product found")
    csvFile.close()
    driver.close()
    print("Done Scrapped : ", outlet)
    print("========================================")
print("ALL TARGET SCRAPPED!!!")
# Out:
# ==>  hypermart-ar-hakim  <==
# ========================================
# <ipython-input-2-f204a9e6668e>:3: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   driver.find_element_by_xpath(xpath)
# fresh produce => No Product found
# pantry and ingredients => No Product found
# meat seafood => No Product found
# dairy eggs => No Product found
# chilled and frozen => No Product found
# Done Scrapped :  hypermart-ar-hakim
# ========================================
# ==>  hero-tunjungan-plaza  <==
# ========================================
# <ipython-input-6-aa1bd6b7725a>:23: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   totproduct = int(driver.find_element_by_xpath(".//span[@class='jsx-4062261742 count']").text);
# <ipython-input-6-aa1bd6b7725a>:28: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   container = driver.find_elements_by_xpath("//div[@class='jsx-2751153571 root small PLP-Common-"+cat+"-product-container']")
# fresh produce => Page :  1 / 7
# C:\Users\HP\Anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py:393: UserWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   warnings.warn("find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead")
# Done!
# fresh produce => Page :  2 / 7 Done!
# fresh produce => Page :  3 / 7 Done!
# fresh produce => Page :  4 / 7 Done!
# fresh produce => Page :  5 / 7 Done!
# fresh produce => Page :  6 / 7 Done!
# fresh produce => Page :  7 / 7 Done!
# pantry and ingredients => Page :  1 / 74 Done!
# pantry and ingredients => Page :  2 / 74 Done!
# pantry and ingredients => Page :  3 / 74 Done!
# pantry and ingredients => Page :  4 / 74 Done!
# pantry and ingredients => Page :  5 / 74 Done!
# pantry and ingredients => Page :  6 / 74 Done!
# pantry and ingredients => Page :  7 / 74 Done!
# pantry and ingredients => Page :  8 / 74 Done!
# pantry and ingredients => Page :  9 / 74 Done!
# pantry and ingredients => Page :  10 / 74 Done!
# pantry and ingredients => Page :  11 / 74 Done!
# pantry and ingredients => Page :  12 / 74 Done!
# pantry and ingredients => Page :  13 / 74 Done!
# pantry and ingredients => Page :  14 / 74 Done!
# pantry and ingredients => Page :  15 / 74 Done!
# pantry and ingredients => Page :  16 / 74 Done!
# pantry and ingredients => Page :  17 / 74 Done!
# pantry and ingredients => Page :  18 / 74 Done!
# pantry and ingredients => Page :  19 / 74 Done!
# pantry and ingredients => Page :  20 / 74 Done!
# pantry and ingredients => Page :  21 / 74 Done!
# pantry and ingredients => Page :  22 / 74 Done!
# pantry and ingredients => Page :  23 / 74 Done!
# pantry and ingredients => Page :  24 / 74 Done!
# pantry and ingredients => Page :  25 / 74 Done!
# pantry and ingredients => Page :  26 / 74 Done!
# pantry and ingredients => Page :  27 / 74 Done!
# pantry and ingredients => Page :  28 / 74 Done!
# pantry and ingredients => Page :  29 / 74 Done!
# pantry and ingredients => Page :  30 / 74 Done!
# pantry and ingredients => Page :  31 / 74 Done!
# pantry and ingredients => Page :  32 / 74 Done!
# pantry and ingredients => Page :  33 / 74 Done!
# pantry and ingredients => Page :  34 / 74 Done!
# pantry and ingredients => Page :  35 / 74 Done!
# pantry and ingredients => Page :  36 / 74 Done!
# pantry and ingredients => Page :  37 / 74 Done!
# pantry and ingredients => Page :  38 / 74 Done!
# pantry and ingredients => Page :  39 / 74 Done!
# pantry and ingredients => Page :  40 / 74 Done!
# pantry and ingredients => Page :  41 / 74 Done!
# pantry and ingredients => Page :  42 / 74 Done!
# pantry and ingredients => Page :  43 / 74 Done!
# pantry and ingredients => Page :  44 / 74 Done!
# pantry and ingredients => Page :  45 / 74 Done!
# pantry and ingredients => Page :  46 / 74 Done!
# pantry and ingredients => Page :  47 / 74 Done!
# ---------------------------------------------------------------------------
# NoSuchWindowException                     Traceback (most recent call last)
# <ipython-input-6-aa1bd6b7725a> in <module>
#      68                 print("Done!")
#      69                 if pagenow != totpage:
# ---> 70                     driver.get(url+cat+plus+str(pagenow+1))
#      71         else :
#      72             print(cat_name+" => No Product found")
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in get(self, url)
#     435         Loads a web page in the current browser session.
#     436         """
# --> 437         self.execute(Command.GET, {'url': url})
#     438
#     439     @property
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     423         response = self.command_executor.execute(driver_command, params)
#     424         if response:
# --> 425             self.error_handler.check_response(response)
#     426             response['value'] = self._unwrap_value(
#     427                 response.get('value', None))
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     245                 alert_text = value['alert'].get('text')
#     246             raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 247         raise exception_class(message, screen, stacktrace)
#     248
#     249     def _value_or_default(self, obj: Mapping[_KT, _VT], key: _KT, default: _VT) -> _VT:
#
# NoSuchWindowException: Message: no such window: target window already closed
# from unknown error: web view not found
#   (Session info: chrome=99.0.4844.84)
# Stacktrace:
# Backtrace:
# 	Ordinal0 [0x00DE9943+2595139]
# 	Ordinal0 [0x00D7C9F1+2148849]
# 	Ordinal0 [0x00C74528+1066280]
# 	Ordinal0 [0x00C5C640+968256]
# 	Ordinal0 [0x00CBE259+1368665]
# 	Ordinal0 [0x00CCB292+1421970]
# 	Ordinal0 [0x00CBB806+1357830]
# 	Ordinal0 [0x00C96086+1204358]
# 	Ordinal0 [0x00C96F96+1208214]
# 	GetHandleVerifier [0x00F8B232+1658114]
# 	GetHandleVerifier [0x0104312C+2411516]
# 	GetHandleVerifier [0x00E7F261+560433]
# 	GetHandleVerifier [0x00E7E366+556598]
# 	Ordinal0 [0x00D8286B+2173035]
# 	Ordinal0 [0x00D875F8+2192888]
# 	Ordinal0 [0x00D876E5+2193125]
# 	Ordinal0 [0x00D911FC+2232828]
# 	BaseThreadInitThunk [0x756FFA29+25]
# 	RtlGetAppContainerNamedObjectPath [0x770C7A9E+286]
# 	RtlGetAppContainerNamedObjectPath [0x770C7A6E+238]

# %%
csvFile.close()
driver.close()
